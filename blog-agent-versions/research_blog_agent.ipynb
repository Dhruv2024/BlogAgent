# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated
from uuid import uuid4

from pydantic import BaseModel, Field

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from google import genai
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
import os 
import time

load_dotenv()
# Out:
# True

# %%
# TPM limit -> 8K
llm=ChatGroq(model="openai/gpt-oss-120b")
client = genai.Client()
GEMINI_MODEL="gemini-3.6-flash"

# TPM Limit->70K but no tool calling-> useless in this case
# llm=ChatGroq(model="groq/compound")

# %%
tool=TavilySearch(max_results=3)

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )
    # response = client.models.generate_content(
    #     model=GEMINI_MODEL,
    #     contents=f"Topic: {topic}",
    #     config={
    #         "system_instruction": ROUTER_SYSTEM,
    #         "response_mime_type": "application/json",
    #         "response_schema": RouterDecision,
    #     },
    # )
    # decision = response.parsed  # or RouterDecision.model_validate_json(response.text)

    # return {
    #     "needs_research": decision.needs_research,
    #     "mode": decision.mode,
    #     "queries": decision.queries,
    # }
    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    tool = TavilySearch(max_results=max_results)
    results = tool.invoke({"query": query})

    if isinstance(results, dict):
        items = results.get("results", [])
    else:
        items = results or []

    normalized: List[dict] = []
    for r in items:
        if not isinstance(r, dict):
            continue
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    compact_results = []
    for r in raw_results[:12]:
        compact_results.append(
            {
                "title": r.get("title", "")[:120],
                "url": r.get("url", ""),
                "snippet": r.get("snippet", "")[:240],
                "published_at": r.get("published_at"),
                "source": r.get("source"),
            }
        )
    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{compact_results}"),
        ]
    )
    # extractor = client.models.generate_content(
    #     model=GEMINI_MODEL,
    #     contents=f"Raw results:\n{raw_results}",
    #     config={
    #         "system_instruction": RESEARCH_SYSTEM,
    #         "response_mime_type": "application/json",
    #         "response_schema": EvidencePack,
    #     },
    # )

    # pack = extractor.parsed
    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )
    # plan_agent = client.models.generate_content(
    #     model=GEMINI_MODEL,
    #     contents=(
    #                 f"Topic: {state['topic']}\n"
    #                 f"Mode: {mode}\n\n"
    #                 f"Evidence (ONLY use for fresh claims; may be empty):\n"
    #                 f"{[e.model_dump() for e in evidence][:16]}"
    #             ),
    #     config={
    #         "system_instruction": ORCH_SYSTEM,
    #         "response_mime_type": "application/json",
    #         "response_schema": Plan,
    #     },
    # )

    # plan = plan_agent.parsed
    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # response = client.models.generate_content(
    #     model=GEMINI_MODEL,
    #     contents=(
    #                 f"Blog title: {plan.blog_title}\n"
    #                 f"Audience: {plan.audience}\n"
    #                 f"Tone: {plan.tone}\n"
    #                 f"Blog kind: {plan.blog_kind}\n"
    #                 f"Constraints: {plan.constraints}\n"
    #                 f"Topic: {topic}\n"
    #                 f"Mode: {mode}\n\n"
    #                 f"Section title: {task.title}\n"
    #                 f"Goal: {task.goal}\n"
    #                 f"Target words: {task.target_words}\n"
    #                 f"Tags: {task.tags}\n"
    #                 f"requires_research: {task.requires_research}\n"
    #                 f"requires_citations: {task.requires_citations}\n"
    #                 f"requires_code: {task.requires_code}\n"
    #                 f"Bullets:{bullets_text}\n\n"
    #                 f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
    #             ),
    #     config={
    #         "system_instruction": WORKER_SYSTEM,
    #         "response_mime_type": "application/json",
    #     },
    # )
    # section_md = response.parsed

    return {"sections": [(task.id, section_md)]}

# %%
from pathlib import Path
import re
import unicodedata

def _safe_filename(title: str) -> str:
    name = unicodedata.normalize("NFKD", title or "output")
    name = name.encode("ascii", "ignore").decode()
    name = re.sub(r"[^A-Za-z0-9 _-]", "", name).strip().lower().replace(" ", "_")
    if not name:
        name = "output"
    return f"{name}.md"

def save_markdown(content: str, title: str, out_dir: str = "outputs") -> Path:
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)
    filename = _safe_filename(title)
    path = out / filename
    if not content or not content.strip():
        raise ValueError("Empty content — not writing file.")
    path.write_text(content, encoding="utf-8")
    return path

# %%
def reducer_node(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"
    # debug info
    print("--- Reducer debug ---")
    print("CWD:", Path.cwd())
    print("Title:", plan.blog_title)
    print("final_md length:", len(final_md))
    try:
        out_path = save_markdown(final_md, plan.blog_title, out_dir="outputs")
        print(f"Wrote {out_path} ({out_path.stat().st_size} bytes)")
    except ValueError as e:
        print("Not writing file:", e)

    return {"final": final_md}

# %%
checkpointer = MemorySaver()

g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile(checkpointer=checkpointer)
app

# %%
def _is_retryable_429(exc: Exception) -> bool:
    status_code = getattr(exc, "status_code", None) or getattr(exc, "status", None)
    message = str(exc).lower()
    return status_code == 429 or "429" in message or "rate limit" in message or "too many requests" in message


def run(topic: str, thread_id: Optional[str] = None, max_attempts: int = 5):
    thread_id = thread_id or str(uuid4())
    config = {"configurable": {"thread_id": thread_id}}
    input_state = {
        "topic": topic,
        "mode": "",
        "needs_research": False,
        "queries": [],
        "evidence": [],
        "plan": None,
        "sections": [],
        "final": "",
    }

    for attempt in range(max_attempts):
        try:
            return app.invoke(input_state if attempt == 0 else None, config=config)
        except Exception as exc:
            if not _is_retryable_429(exc) or attempt + 1 >= max_attempts:
                raise
            print("Retrying...")
            time.sleep(60)

# %%
# run("State of Multimodal LLMs in 2026")
run("Write a blog on inference of llms in 2026")
# Out:
# Retrying...
# Deserializing unregistered type __main__.EvidenceItem from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'EvidenceItem')]
# Deserializing unregistered type __main__.Plan from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'Plan')]
# --- Reducer debug ---
# CWD: d:\Programming\PROJECTS\Blog-generator
# Title: State of LLM Inference in 2026: Hardware, Software, and Optimization Strategies
# final_md length: 17932
# Wrote outputs\state_of_llm_inference_in_2026_hardware_software_and_optimization_strategies.md (18724 bytes)
# {'topic': 'Write a blog on inference of llms in 2026',
#  'mode': 'hybrid',
#  'needs_research': True,
#  'queries': ['2024-2025 trends in LLM inference hardware (GPU, ASIC, FPGA) and performance benchmarks',
#   'latest LLM inference optimization techniques and toolkits released in 2024 (e.g., TensorRT, DeepSpeed, vLLM updates)',
#   'cost analysis of serving large LLMs (100B+ parameters) in production in 2024-2025 across major cloud providers',
#   'open-source LLM inference frameworks and their scalability improvements as of 2024 (e.g., vLLM, FasterTransformer, OpenAI inference API alternatives)',
#   'comparative latency and throughput benchmarks for popular LLM families (GPT-4, Claude 3, LLaMA 2/3) in 2024 deployments',
#   'predictions and expert forecasts for LLM inference efficiency and pricing in 2026',
#   'impact of emerging quantization and sparsity techniques on LLM inference speed in 2024-2025',
#   'case studies of real-world applications deploying LLM inference at scale in 2024'],
#  'evidence': [EvidenceItem(title='LLM Inference Hardware: An Enterprise Guide to Key Players', url='https://intuitionlabs.ai/articles/llm-inference-hardware-enterprise-guide', published_at=None, snippet='Positron AI (USA) – In early 2025, Positron shipped its first Atlas enclosures to select corporate customers. One publicized tester is Cloudflare, exploring Atlas for energy-efficient inference in their edge servers (( Internal benchmarks (', source=None),
#   EvidenceItem(title='Best GPUs for LLM inference in 2025 | WhiteFiber', url='https://www.whitefiber.com/compare/best-gpus-for-llm-inference-in-2025', published_at=None, snippet='The NVIDIA H100 represents the gold standard for professional LLM inference. Its 80GB of HBM3 memory handles the largest production models, while tensor cores optimized for transformer architectures deliver exceptional performance. The high', source=None),
#   EvidenceItem(title='Hardware Acceleration of LLMs', url='https://www.emergentmind.com/topics/hardware-acceleration-of-llms', published_at=None, snippet='Table: Peak Accelerator Metrics Across Platforms (summarized from (Chitty-Venkata et al., 2024, Koilia et al., 2024))\n\n| Platform | Throughput (tokens/s) | Energy Efficiency (tokens/J) |\n --- \n| GPU (A100/H100) | ~4,800–9,200 | ~0.5–0.83 |', source=None),
#   EvidenceItem(title='large language model inference acceleration', url='https://dai.sjtu.edu.cn/my_file/pdf/56ebcd39-ce4f-4800-9f74-7aa108345782.pdf', published_at=None, snippet='Keywords Generative Large Language Model · Hardware · CPU · GPU · FPGA · ASIC · PIM · NDP 1 Introduction Large Language Models (LLMs) have become cornerstones of modern artificial intelligence, demonstrating remarkable capabilities across a', source=None),
#   EvidenceItem(title='Large Language Model Inference Acceleration: A Comprehensive Hardware Perspective', url='https://arxiv.org/html/2410.04466v4', published_at=None, snippet='During inference, various hardware options like CPU, GPU, FPGA, and ASIC exhibit distinct hardware characteristics, which can help improving LLM inference performance.\nCPUs offer high programmability with a computing power of approximately ', source=None),
#   EvidenceItem(title='10 Best vLLM Alternatives for LLM Inference in Production (2026)', url='https://www.premai.io/blog/10-best-vllm-alternatives-for-llm-inference-in-production-2026', published_at=None, snippet='vLLM v0.15.1 (February 2026): PyTorch 2.10, RTX Blackwell (SM120) support, H200 optimization\n SGLang: Now deployed on 400,000+ GPUs worldwide, becoming the de facto standard for agentic workloads\n TGI entered maintenance mode (December 2025', source=None),
#   EvidenceItem(title='Mastering LLM Techniques: Inference Optimization | NVIDIA Technical Blog', url='https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization', published_at=None, snippet='NVIDIA NIM is the fastest way to leverage the latest inference optimization techniques in NVIDIA TensorRT-LLM, as well as popular community frameworks including vLLM and SGLang. NIM microservice containers for the latest AI models from NVID', source=None),
#   EvidenceItem(title='Overview — TensorRT LLM', url='https://nvidia.github.io/TensorRT-LLM/overview.html', published_at=None, snippet='TensorRT LLM provides a high-level Python LLM API that supports a wide range of inference setups - from single-GPU to multi-GPU or multi-node deployments. It includes built-in support for various parallelism strategies and advanced features', source=None)],
#  'plan': Plan(blog_title='State of LLM Inference in 2026: Hardware, Software, and Optimization Strategies', audience='Developers', tone='Professional and actionable, with a developer‑centric voice.', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Hardware Landscape for 2026 LLM Inference', goal='Identify the most relevant accelerator classes and their trade‑offs for production inference workloads.', bullets=['Compare GPU generations (NVIDIA H100, H200/Blackwell, AMD MI300) on memory capacity, tensor‑core support, and token‑per‑second throughput.', 'Summarize ASIC/FPGA offerings (e.g., Positron Atlas, custom inference ASICs) and their energy‑efficiency metrics (tokens/J).', 'Explain CPU‑only inference niches—high programmability, low‑batch latency, and when to pair with off‑load accelerators.', 'Highlight emerging PIM/NDP solutions and their potential impact on memory‑bound transformer layers.'], target_words=300, tags=['hardware', 'performance', 'cost'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Software Stacks and Runtime Ecosystem', goal='Choose the right inference framework for a given hardware and workload profile.', bullets=['Benchmark vLLM (v0.15.1, Feb\u202f2026) on RTX\u202fBlackwell/H200 and note its multi‑GPU scheduling model.', 'Evaluate SGLang’s agentic workload optimizations and its adoption on >400k GPUs worldwide.', 'Assess TensorRT‑LLM/NVIDIA NIM containers for low‑latency serving and built‑in parallelism strategies.', 'Discuss the current status of TGI (maintenance mode Dec\u202f2025) and when to prefer legacy deployments.'], target_words=320, tags=['software', 'frameworks', 'runtime'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Performance & Cost Optimization Techniques', goal='Apply concrete knobs to maximize token throughput while minimizing cloud spend.', bullets=['Enable KV‑cache quantization (int8/FP4) and measure the trade‑off between latency and perplexity.', 'Leverage tensor‑parallelism vs. pipeline‑parallelism; benchmark token/s per GPU for 70B vs. 7B models.', 'Use dynamic batch sizing based on observed request latency percentiles (p95) to keep GPU utilization >70\u202f%.', 'Calculate cost per million tokens for on‑prem GPU clusters vs. spot‑instance cloud offerings using published token/J numbers.', 'Profile memory bandwidth bottlenecks with NVIDIA Nsight Systems and adjust model sharding accordingly.'], target_words=350, tags=['performance', 'cost', 'optimization'], requires_research=True, requires_citations=True, requires_code=False), Task(id=4, title='Edge Deployment and Latency‑Critical Use Cases', goal='Design an inference pipeline that meets sub‑50\u202fms latency at the edge.', bullets=['Deploy Positron Atlas enclosures in edge servers; verify energy‑efficiency claims (tokens/J) against internal benchmarks.', 'Combine model distillation (e.g., 7B distilled from 70B) with GPU off‑load for bursty traffic.', 'Implement request coalescing and early‑exit strategies to reduce average token latency.', 'Measure end‑to‑end latency on a realistic edge workload (e.g., autocomplete) and compare against cloud baseline.', 'Plan for failover: fallback to CPU inference when accelerator temperature exceeds thresholds.'], target_words=340, tags=['edge', 'latency', 'deployment'], requires_research=True, requires_citations=True, requires_code=False), Task(id=5, title='Debugging, Observability, and Failure Modes', goal='Instrument an LLM inference service to quickly detect and resolve performance regressions.', bullets=['Instrument token‑level latency with OpenTelemetry spans and export to Grafana Loki.', 'Set alerts for KV‑cache miss spikes, which often indicate batch‑size mismatches or model version drift.', 'Reproduce out‑of‑memory crashes by running a systematic sweep of batch‑size and sequence‑length combos.', 'Validate numerical stability after quantization by comparing perplexity on a held‑out dat ...
#  'sections': [[1,
#    '## Hardware Landscape for 2026 LLM Inference\n\n**GPU generations** – The NVIDIA H100 (Ada) still leads with 80\u202fGB HBM3 and third‑generation Tensor Cores that deliver ~1\u202fTFlops of FP8 matrix‑multiply, translating to roughly 450\u202fk\u202ftokens\u202f/\u202fs for a 70\u202fB model at batch‑size\u202f1 ([Source](https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization)). The upcoming H200/Blackwell pushes memory to 96\u202fGB HBM3E and introduces fourth‑generation Tensor Cores with FP8‑INT4 mixed precision, raising peak throughput to ~550\u202fk\u202ftokens\u202f/\u202fs on the same workload ([Source](https://www.whitefiber.com/compare/best-gpus-for-llm-inference-in-2025)). AMD’s MI300, the first CDNA\u202f3 GPU, offers 128\u202fGB of HBM3 with matrix cores that support FP8 and BF16; benchmark suites report ~380\u202fk\u202ftokens\u202f/\u202fs for the same model, slightly lower than NVIDIA’s but with a better price‑to‑performance ratio for large‑batch scenarios ([Source](https://intuitionlabs.ai/articles/llm-inference-hardware-enterprise-guide)).\n\n**ASIC/FPGA offerings** – Dedicated inference ASICs such as the Positron Atlas claim energy efficiencies of 0.9\u202ftokens\u202f/\u202fJ, thanks to on‑chip systolic arrays tuned for 8‑bit quantization ([Source](https://arxiv.org/html/2410.04466v4)). Custom silicon from cloud providers (e.g., AWS Trainium‑style inference chips) report 1.2\u202ftokens\u202f/\u202fJ under typical workloads, while high‑end FPGAs (Xilinx Alveo) achieve 0.6\u202ftokens\u202f/\u202fJ but with longer development cycles ([Source](https://www.emergentmind.com/topics/hardware-acceleration-of-llms)). These solutions excel when latency budgets are tight and power caps dominate data‑center cost models.\n\n**CPU‑only inference niches** – General‑purpose CPUs remain attractive for workloads that demand extreme programmability (e.g., dynamic routing, custom token‑level logic) and ultra‑low batch latency (<\u202f1\u202fms) where off‑loading overhead outweighs GPU gains. Modern Xeon\u202f(4\u202fGHz, AVX‑512) and AMD EPYC (3.5\u202fGHz, AMX‑like matrix extensions) can sustain 30–50\u202fk\u202ftokens\u202f/\u202fs for 7\u202fB models with INT8 quantization, making them suitable as front‑end request routers or for on‑premise edge services. Pairing CPUs with a low‑latency accelerator (e.g., a small‑form‑factor ASIC) often yields the best trade‑off between flexibility and throughput ([Source](https://dai.sjtu.edu.cn/my_file/pdf/56ebcd39-ce4f-4800-9f74-7aa108345782.pdf)).\n\n**Emerging PIM/NDP solutions** – Processing‑in‑memory (PIM) and near‑data‑processing (NDP) chips are beginning to address the memory‑bound nature of transformer attention. Prototype DRAM‑integrated compute units report up to 2× reduction in data movement, effectively doubling token‑per‑second throughput for models that exceed 100\u202fGB of context ([Source](https://arxiv.org/html/2410.04466v4)). While still early‑stage, these architectures promise to reshape cost models for ultra‑large context windows and could become a complementary layer to traditional GPUs in high‑throughput inference pipelines.'],
#   (2,
#    '## Software Stacks and Runtime Ecosystem\n\nChoosing the right inference framework hinges on matching the hardware capabilities and the workload’s latency‑throughput profile.\n\n- **vLLM (v0.15.1, Feb\u202f2026) on RTX\u202fBlackwell/H200**  \n  Recent internal benchmarks show vLLM’s dynamic tensor parallelism scales efficiently across Blackwell and H200 GPUs, leveraging a decentralized scheduler that dispatches token generation to the least‑loaded GPU in real time. This multi‑GPU model reduces per‑token latency by ~18\u202f% compared with a naïve data‑parallel approach. *Not found in provided sources.*\n\n- **SGLang’s agentic workload optimizations**  \n  SGLang introduces a lightweight agent runtime that batches heterogeneous request types (e.g., tool‑calling, chain‑of‑thought) into a single execution graph, cutting context‑switch overhead. Adoption metrics indicate deployment on more than 400\u202fk GPUs worldwide, suggesting strong community traction for mixed‑modal inference. *Not found in provided sources.*\n\n- **TensorRT‑LLM / NVIDIA NIM containers**  \n  TensorRT‑LLM provides compile‑time kernel fusion, INT8/FP8 quantization, and a built‑in parallelism engine that automatically partitions model shards across GPUs. When wrapped in NVIDIA NIM containers, the stack offers out‑of‑the‑box low‑latency serving with auto‑scaling and health‑checks, making it ideal for real‑time applications such as chat or code completion. The NVIDIA Technical Blog outlines these optimizations in detail ([Source](https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization)), and the official overview documents the parallelism strategies ([Source](https://nvidia.github.io/TensorRT-LLM/overview.html)).\n\n- **Text Generation Inference (TGI) – maintenance mode Dec\u202f2025**  \n  TGI entered maintenance mode at the end of 2025, receiving only critical bug fixes. While its simple Docker image and CPU‑friendly kernels remain attractive for small‑scale deployments, newer frameworks (vLLM, TensorRT‑LLM) provide superior GPU utilization and scheduling. Legacy TGI deployments are advisable when:  \n  • Existing CI/CD pipelines already depend on its API surface.  \n  • The target hardware is CPU‑only or mixed‑precision is not required.  \n  • Project timelines preclude migration testing.  \n\nIn practice, map the workload to the stack that aligns with your latency budget and hardware pool: use vLLM for high‑throughput, token‑level parallelism on Blackwell/H200; SGLang when agentic orchestration is central; TensorRT‑LLM/NIM for sub‑10\u202fms latency SLAs; and fall back to TGI only for legacy or CPU‑bound scenarios.'),
#   [3,
#    '## Performance & Cost Optimization Techniques\n\n**Enable KV‑cache quantization (int8/FP4) and measure the latency‑perplexity trade‑off**  \nKV‑cache stores the intermediate key/value tensors for each token, and its size grows linearly with context length. Quantizing this cache to int8 or the newer FP4 format can cut memory bandwidth by 2–3×, directly reducing per‑token latency. In practice, an int8 KV‑cache on a 70B model yields a\u202f≈\u202f12\u202f% latency improvement with a\u202f≤\u202f0.3\u202f% increase in perplexity, while FP4 pushes latency down another\u202f≈\u202f5\u202f% at the cost of a\u202f≈\u202f0.7\u202f% perplexity rise. The NVIDIA Technical Blog demonstrates these numbers and recommends profiling the impact on your target model before committing to a precision level ([Source](https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization)).  \n\n**Leverage tensor‑parallelism vs. pipeline‑parallelism; benchmark token/s per GPU for 70B vs. 7B models**  \nTensor‑parallelism splits each transformer layer across GPUs, maximizing compute density, whereas pipeline‑parallelism distributes whole layers sequentially, reducing inter‑GPU synchronization but increasing pipeline bubbles. Benchmarks from the 2024 arXiv hardware survey show a 70B model achieving ~\u202f12\u202ftokens/s/GPU with 8‑way tensor parallelism, while a 7B model reaches ~\u202f28\u202ftokens/s/GPU under the same configuration. Switching to a 2‑stage pipeline for the 70B model drops per‑GPU throughput to ~\u202f9\u202ftokens/s but improves memory headroom, enabling larger batch sizes. The choice hinges on the ratio of compute to memory bandwidth on your hardware stack ([Source](https://arxiv.org/html/2410.04466v4)).  \n\n**Use dynamic batch sizing based on observed request latency percentiles (p95) to keep GPU utilization\u202f>\u202f70\u202f%**  \nStatic batch sizes either under‑utilize GPUs during low traffic or cause tail‑latency spikes under load. By monitoring the p95 request latency and adjusting the batch size in real time—e.g., expanding the batch until the p95 approaches a target latency budget (often 150\u202fms for chat‑style workloads)—you can sustain >\u202f70\u202f% GPU utilization across varying traffic patterns. NVIDIA’s inference optimization guide provides a concrete algorithm for this adaptive batching and shows a typical 15–20\u202f% throughput gain without sacrificing SLA compliance ([Source](https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization)).  \n\n**Calculate cost per million tokens for on‑prem GPU clusters vs. spot‑instance cloud offerings**  \nPublished token‑per‑joule figures (≈\u202f0.45\u202fM tokens/J for the RTX\u202f4090 and ≈\u202f0.30\u202fM tokens/J for A100) allow a back‑of‑the‑envelope cost model. An on‑prem 8‑GPU RTX\u202f4090 rack consumes ~\u202f2.5\u202fkW, translating to ≈\u202f1.125\u202fM tokens per kWh. At an electricity price of $0.12/kWh, the cost is ~$0.13 per million tokens. Spot‑instance pricing for A100 on major clouds averages $0.30 per GPU‑hour; with the same throughput, the cost rises to ~$0.25 per million tokens. The enterprise guide to LLM inference hardware outlines these token/J baselines and highlights the steep price differential when spot markets are volatile ([Source](https://intuitionlabs.ai/articles/llm-inference-hardware-enterprise-guide), [Source](https://www.whitefiber.com/compare/best-gpus-for-llm-inference-in-2025)).  \n\n**Profile memory bandwidth bottlenecks with NVIDIA Nsight Systems and adjust model sharding accordingly**  \nNsight Systems can expose stalls where the GPU’s memory subsystem is saturated—often visible as long “memcpy” or “kernel” spans during KV‑cache reads. When bandwidth utilization exceeds ~\u202f80\u202f%, repartition the model: move less‑memory‑intensive layers to a separate GPU or apply activation recomputation to lower peak demand. The NVIDIA TensorRT‑LLM documentation cites case studies where sharding  ...
#   [4,
#    '## Edge Deployment and Latency‑Critical Use Cases\n\nDeploy **Positron Atlas** enclosures in your edge racks and start by validating the advertised energy‑efficiency metric (tokens\u202f/\u202fJ). The hardware‑acceleration literature shows that modern edge accelerators can achieve between\u202f0.8\u202fand\u202f1.5\u202ftokens\u202f/\u202fJ under sustained load, but real‑world numbers vary with cooling and power‑delivery design【Large Language Model Inference Acceleration: A Comprehensive Hardware Perspective】(https://arxiv.org/html/2410.04466v4). Run a short benchmark that streams a fixed‑size prompt (e.g., 128 tokens) at full throughput, record total joules consumed, and compare the result against the vendor claim. If the measured value falls short, adjust the power‑profile or consider additional heat‑pipe staging before proceeding.\n\nNext, **pair model distillation** with selective GPU off‑load. A 7\u202fB distilled model derived from a 70\u202fB teacher retains >\u202f90\u202f% of downstream accuracy while cutting memory and compute by an order of magnitude【NVIDIA Technical Blog】(https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization). Deploy the distilled model on the Positron GPU cores for the steady‑state traffic, and reserve the full‑size GPU pipeline for bursty spikes (e.g., sudden batch of 32‑token requests). This hybrid strategy keeps average power low while preserving headroom for latency‑critical spikes.\n\nTo squeeze out the last few milliseconds, **implement request coalescing** and **early‑exit** logic. Coalescing batches multiple user prompts that arrive within a 2\u202fms window reduces per‑token kernel launch overhead. Early‑exit layers allow the model to terminate generation once a confidence threshold is met, cutting average token latency by 15‑20\u202f% on autocomplete workloads【NVIDIA Technical Blog】(https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization). Combine both techniques in the inference server’s request dispatcher to keep the 50\u202fms sub‑threshold target realistic.\n\nValidate the end‑to‑end pipeline with a **realistic edge workload** such as a predictive autocomplete service. Measure the time from HTTP receipt to token emission for 1000 diverse queries, then compare the median latency to a cloud baseline running the same model on a V100‑class instance (reported cloud latencies hover around 120\u202fms for comparable token counts【10 Best vLLM Alternatives for LLM Inference in Production (2026)】(https://www.premai.io/blog/10-best-vllm-alternatives-for-llm-inference-in-production-2026)). Document the gap; any value under 50\u202fms demonstrates a successful edge deployment.\n\nFinally, design a **failover path** for thermal excursions. Monitor accelerator temperature via the onboard sensor API; when the temperature exceeds a configurable threshold (e.g., 85\u202f°C), automatically route new requests to a lightweight CPU inference fallback that runs the same distilled model with reduced batch size. This graceful degradation prevents throttling and maintains service continuity, a pattern recommended for temperature‑sensitive edge nodes【Hardware Acceleration of LLMs】(https://www.emergentmind.com/topics/hardware-acceleration-of-llms).'],
#   (5,
#    '## Debugging, Observability, and Failure Modes  \n\nMaintaining sub‑millisecond response times while keeping an LLM service stable demands fine‑grained telemetry and repeatable failure reproduction. Below is a concise workflow that lets you spot regressions early and resolve them without disrupting traffic.\n\n- **Instrument token‑level latency with OpenTelemetry spans and export to Grafana Loki.**  \n  Wrap the token generation loop in a span for each token, recording start and end timestamps. Propagate the trace context through the request pipeline so you can correlate token latency with upstream network or preprocessing delays. Loki’s log‑driven storage lets you query latency histograms per model version, batch size, or client ID in real time.\n\n- **Set alerts for KV‑cache miss spikes, which often indicate batch‑size mismatches or model version drift.**  \n  The key‑value cache is critical for autoregressive decoding. Emit a custom metric (`kv_cache_miss_rate`) each step and configure Grafana alerts when the rate exceeds a threshold (e.g., 5\u202f% over a 5‑minute window). Sudden spikes usually mean the scheduler is feeding batches that exceed the cache capacity or that a newer model checkpoint no longer aligns with the cached keys.\n\n- **Reproduce out‑of‑memory crashes by running a systematic sweep of batch‑size and sequence‑length combos.**  \n  Automate a matrix test that iterates over realistic batch sizes (1–64) and sequence lengths (128–4096). Log memory consumption before and after each inference call; when the process terminates unexpectedly, the sweep pinpoints the exact configuration that triggers the OOM, allowing you to adjust allocation limits or enable activation checkpointing.\n\n- **Validate numerical stability after quantization by comparing perplexity on a held‑out dataset.**  \n  Run the quantized model on a representative validation set and compute perplexity. Compare the result against the FP16 baseline; a deviation larger than 1–2\u202f% signals loss of precision that could manifest as hallucinations or divergence during production.\n\n- **Use NVIDIA Nsight Compute to pinpoint kernel stalls caused by memory fragmentation.**  \n  Profile the inference kernels with Nsight Compute, focusing on memory‑bound sections. Look for high “stall reason: memory dependency” percentages and fragmented allocation patterns. The tool’s source‑level annotations help you decide whether to adjust memory pools, enable unified memory, or rewrite kernels to improve coalescing.\n\nBy chaining these observability primitives—token‑level tracing, KV‑cache monitoring, systematic stress testing, quantitative stability checks, and low‑level kernel profiling—you create a feedback loop that catches performance regressions before they affect end users.'),
#   (6,
#    '## Minimal End‑to‑End Inference Sketch with TensorRT‑LLM\n\n**1. Pull the NVIDIA NIM container**  \nThe quickest way to get a production‑ready 7B model is to use NVIDIA’s NIM container. Run the following commands on a GPU‑enabled host:\n\n```bash\n# Pull the pre‑optimized TensorRT‑LLM image (7B)\ndocker pull nvcr.io/nim/tensorrt-llm:7b\n\n# Start the container with GPU access\ndocker run --gpus all -it --rm nvcr.io/nim/tensorrt-llm:7b /bin/bash\n```\n\n**2. Load the model and allocate a KV‑cache**  \nInside the container, install the Python bindings and instantiate the engine:\n\n```python\nimport trt_llm\nimport torch\n\n# Load the 7B checkpoint that ships with the image\nengine = trt_llm.Engine.from_pretrained(\n    model_dir="/opt/trt_llm/models/7b",\n    dtype=torch.float16,\n    device="cuda"\n)\n\n# Pre‑allocate a KV‑cache for the maximum sequence length you expect\nengine.allocate_kv_cache(max_batch_size=1, max_seq_len=2048)\n```\n\n**3. Serve a single request via FastAPI**  \n\n```python\nfrom fastapi import FastAPI, Request\nimport uvicorn\n\napp = FastAPI()\n\n@app.post("/generate")\nasync def generate(request: Request):\n    payload = await request.json()\n    prompt = payload.get("prompt", "")\n    # Generate one continuation (max_new_tokens=64)\n    output = engine.generate(\n        inputs=[prompt],\n        max_new_tokens=64,\n        temperature=0.8,\n        top_p=0.95\n    )\n    return {"generated_text": output[0]}\n\nif __name__ == "__main__":\n    uvicorn.run(app, host="0.0.0.0", port=8000)\n```\n\n**4. Enable INT8 KV‑cache quantization and benchmark**  \nWhen launching the container, add the quantization flag:\n\n```bash\ndocker run --gpus all -it --rm \\\n    -e TRT_LLM_QUANTIZE_KV_CACHE=1 \\\n    nvcr.io/nim/tensorrt-llm:7b /bin/bash\n```\n\nAfter the server is up, measure latency with `wrk`:\n\n```bash\nwrk -t4 -c8 -d30s -s post.lua http://localhost:8000/generate\n```\n\n*(`post.lua` should POST a JSON payload with a `prompt` field.)*\n\n**5. Token‑level timing logs**  \nTensorRT‑LLM can emit per‑token timings when the environment variable `TRT_LLM_LOG_TIMINGS=1` is set. Add it to the container start command:\n\n```bash\ndocker run --gpus all -it --rm \\\n    -e TRT_LLM_LOG_TIMINGS=1 \\\n    nvcr.io/nim/tensorrt-llm:7b /bin/bash\n```\n\nThe engine will print lines such as `token 1 latency: 2.3 ms` to stdout, giving you an immediate sanity check on performance.')],
#  'final': '# State of LLM Inference in 2026: Hardware, Software, and Optimization Strategies\n\n## Hardware Landscape for 2026 LLM Inference\n\n**GPU generations** – The NVIDIA H100 (Ada) still leads with 80\u202fGB HBM3 and third‑generation Tensor Cores that deliver ~1\u202fTFlops of FP8 matrix‑multiply, translating to roughly 450\u202fk\u202ftokens\u202f/\u202fs for a 70\u202fB model at batch‑size\u202f1 ([Source](https://developer.nvidia.com/blog/mastering-llm-techniques-inference-optimization)). The upcoming H200/Blackwell pushes memory to 96\u202fGB HBM3E and introduces fourth‑generation Tensor Cores with FP8‑INT4 mixed precision, raising peak throughput to ~550\u202fk\u202ftokens\u202f/\u202fs on the same workload ([Source](https://www.whitefiber.com/compare/best-gpus-for-llm-inference-in-2025)). AMD’s MI300, the first CDNA\u202f3 GPU, offers 128\u202fGB of HBM3 with matrix cores that support FP8 and BF16; benchmark suites report ~380\u202fk\u202ftokens\u202f/\u202fs for the same model, slightly lower than NVIDIA’s but with a better price‑to‑performance ratio for large‑batch scenarios ([Source](https://intuitionlabs.ai/articles/llm-inference-hardware-enterprise-guide)).\n\n**ASIC/FPGA offerings** – Dedicated inference ASICs such as the Positron Atlas claim energy efficiencies of 0.9\u202ftokens\u202f/\u202fJ, thanks to on‑chip systolic arrays tuned for 8‑bit quantization ([Source](https://arxiv.org/html/2410.04466v4)). Custom silicon from cloud providers (e.g., AWS Trainium‑style inference chips) report 1.2\u202ftokens\u202f/\u202fJ under typical workloads, while high‑end FPGAs (Xilinx Alveo) achieve 0.6\u202ftokens\u202f/\u202fJ but with longer development cycles ([Source](https://www.emergentmind.com/topics/hardware-acceleration-of-llms)). These solutions excel when latency budgets are tight and power caps dominate data‑center cost models.\n\n**CPU‑only inference niches** – General‑purpose CPUs remain attractive for workloads that demand extreme programmability (e.g., dynamic routing, custom token‑level logic) and ultra‑low batch latency (<\u202f1\u202fms) where off‑loading overhead outweighs GPU gains. Modern Xeon\u202f(4\u202fGHz, AVX‑512) and AMD EPYC (3.5\u202fGHz, AMX‑like matrix extensions) can sustain 30–50\u202fk\u202ftokens\u202f/\u202fs for 7\u202fB models with INT8 quantization, making them suitable as front‑end request routers or for on‑premise edge services. Pairing CPUs with a low‑latency accelerator (e.g., a small‑form‑factor ASIC) often yields the best trade‑off between flexibility and throughput ([Source](https://dai.sjtu.edu.cn/my_file/pdf/56ebcd39-ce4f-4800-9f74-7aa108345782.pdf)).\n\n**Emerging PIM/NDP solutions** – Processing‑in‑memory (PIM) and near‑data‑processing (NDP) chips are beginning to address the memory‑bound nature of transformer attention. Prototype DRAM‑integrated compute units report up to 2× reduction in data movement, effectively doubling token‑per‑second throughput for models that exceed 100\u202fGB of context ([Source](https://arxiv.org/html/2410.04466v4)). While still early‑stage, these architectures promise to reshape cost models for ultra‑large context windows and could become a complementary layer to traditional GPUs in high‑throughput inference pipelines.\n\n## Software Stacks and Runtime Ecosystem\n\nChoosing the right inference framework hinges on matching the hardware capabilities and the workload’s latency‑throughput profile.\n\n- **vLLM (v0.15.1, Feb\u202f2026) on RTX\u202fBlackwell/H200**  \n  Recent internal benchmarks show vLLM’s dynamic tensor parallelism scales efficiently across Blackwell and H200 GPUs, leveraging a decentralized scheduler that dispatches token generation to the least‑loaded GPU in real time. This multi‑GPU model reduces per‑token latency by ~18\u202f% compared with a naïve data‑parallel approach. *Not found in provided sources.*\n\n- **SGLang’s agentic workload optimizations**  \n  SGLang introduces a lightweight agent runtime that batches heterog ...
