# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
import os 

load_dotenv()
# Out:
# True

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3–5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm=ChatGroq(model="openai/gpt-oss-120b")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path
import re
import unicodedata

def _safe_filename(title: str) -> str:
    name = unicodedata.normalize("NFKD", title or "output")
    name = name.encode("ascii", "ignore").decode()
    name = re.sub(r"[^A-Za-z0-9 _-]", "", name).strip().lower().replace(" ", "_")
    if not name:
        name = "output"
    return f"{name}.md"

def save_markdown(content: str, title: str, out_dir: str = "outputs") -> Path:
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)
    filename = _safe_filename(title)
    path = out / filename
    if not content or not content.strip():
        raise ValueError("Empty content — not writing file.")
    path.write_text(content, encoding="utf-8")
    return path

def reducer(state: State) -> dict:
    title = state["plan"].blog_title
    sections = state.get("sections", [])
    body = "\n\n".join(sections).strip()
    final_md = f"# {title}\n\n{body}\n"
    # debug info
    print("--- Reducer debug ---")
    print("CWD:", Path.cwd())
    print("Title:", title)
    print("final_md length:", len(final_md))
    try:
        out_path = save_markdown(final_md, title, out_dir="outputs")
        print(f"Wrote {out_path} ({out_path.stat().st_size} bytes)")
    except ValueError as e:
        print("Not writing file:", e)

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})
# Out:
# --- Reducer debug ---
# CWD: d:\Programming\PROJECTS\Blog-generator
# Title: Demystifying Self‑Attention: From Theory to Production‑Ready Code
# final_md length: 13536
# Wrote outputs\demystifying_selfattention_from_theory_to_productionready_code.md (14146 bytes)

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Demystifying Self‑Attention: From Theory to Production‑Ready Code', audience='Software engineers and ML practitioners building or optimizing transformer models', tone='practical, crisp', tasks=[Task(id=1, title='Why Self‑Attention? The problem it solves', goal='Understand the limitations of recurrent/convolutional encoders and why self‑attention became the backbone of modern NLP and vision models.', bullets=['Compare sequence length vs. receptive field of RNNs and CNNs using a concrete example (e.g., 512‑token text classification).', 'Show a simple timing chart that demonstrates O(n²) attention cost vs. O(n) recurrence cost for long sequences.', 'Explain how self‑attention enables direct token‑to‑token communication, eliminating the vanishing‑gradient bottleneck.', 'Summarize the key design goals: parallelism, long‑range dependency capture, and flexible context size.'], target_words=190, section_type='intro'), Task(id=2, title='Scaled Dot‑Product Attention: Intuition and Math', goal='Derive the scaled dot‑product formula and grasp the role of queries, keys, values, and the scaling factor.', bullets=['Write the full matrix form QKᵀ/√dₖ and walk through a 2‑token, dₖ=4 example with hand‑computed scores.', 'Explain why dividing by √dₖ stabilizes softmax gradients; verify by plotting softmax entropy for dₖ∈{16,256,1024}.', 'Show how masking (causal or padding) is injected as an additive large‑negative bias before softmax.', 'Derive the multi‑head extension and list the shape transformations for Q, K, V, and the concatenated output.'], target_words=230, section_type='core'), Task(id=3, title='Building a Self‑Attention Layer from Scratch (PyTorch MWE)', goal='Implement a minimal, testable self‑attention module and run a sanity‑check forward pass.', bullets=['Provide a 12‑line PyTorch class that creates Q, K, V linear projections, applies scaling, masking, and softmax, then recombines heads.', 'Add a unit test that feeds a batch of random tensors (batch=2, seq=8, dim=32) and asserts output shape = (2,8,32).', 'Instrument the forward pass with torch.autograd.profiler to log per‑head FLOPs and memory usage.', 'Show how to replace the custom layer with nn.MultiheadAttention and verify identical output on the same seed.'], target_words=260, section_type='examples'), Task(id=4, title='Performance, Cost, and Edge‑Case Scaling', goal='Identify the main bottlenecks of self‑attention and evaluate trade‑offs for long sequences and large models.', bullets=['Benchmark O(n²) memory growth on GPU for seq lengths 256, 512, 1024 using the MWE; record peak allocation and runtime.', 'Explain two common mitigation strategies: (a) sparse/local attention patterns, (b) reversible/recurrent chunking, and provide a code sketch for each.', 'List failure modes when seq_len exceeds GPU memory (OOM) and how to catch them via torch.cuda.OutOfMemoryError handling.', 'Quantify the latency impact of increasing the number of heads from 4 to 16 on a fixed model dimension.'], target_words=250, section_type='core'), Task(id=5, title='Common Mistakes When Using Self‑Attention', goal='Recognize frequent pitfalls and apply concrete fixes before they cause training instability or silent bugs.', bullets=['Forgetting the √dₖ scaling – reproduce the exploding‑gradient symptom by removing the factor and show the loss curve divergence.', 'Applying padding mask after softmax – demonstrate incorrect attention distribution and then correct it by masking pre‑softmax.', 'Re‑using the same linear projection for Q, K, V without a separate weight matrix – explain why weight sharing degrades representation power; provide a diff patch to add distinct layers.', 'Neglecting dtype consistency (e.g., mixing fp16 Q with fp32 K) – add a debugging tip that prints tensor.dtype before the matmul and fixes it with .to(dtype).'], target_words=210, section_type='common_mistakes'), Task(id=6, title='Production Checklist & Next Steps', goal='Equip the reader with a ready‑to‑u ...
#  'sections': ['## Why Self‑Attention? The problem it solves  \n\n* **RNN/CNN receptive field vs. sequence length** – In a 512‑token sentiment classifier, a vanilla LSTM processes tokens one‑by‑one, so the hidden state at position\u202f512 has only seen 511 previous steps through a single recurrent path. A 1‑D CNN with kernel\u202f3 and 4 layers reaches a receptive field of\u202f3\u202f+\u202f2·(4‑1)\u202f=\u202f9 tokens, leaving 503 tokens outside the context. Neither architecture can natively attend to the whole 512‑token span without stacking many layers, which inflates latency and memory.  \n\n* **Timing chart (theoretical ops)**  \n\n| Sequence length *n* | Recurrence (O(n)) | Self‑attention (O(n²)) |\n|---------------------|-------------------|------------------------|\n| 128                 | 128\u202f×\u202fC           | 16\u202f384\u202f×\u202fC             |\n| 512                 | 512\u202f×\u202fC           | 262\u202f144\u202f×\u202fC            |\n| 2048                | 2\u202f048\u202f×\u202fC         | 4\u202f194\u202f304\u202f×\u202fC          |\n\n*C = constant per‑element work.* The table shows that for short sequences recurrence is cheaper, but the quadratic term dominates as *n* grows, motivating optimized attention kernels (e.g., FlashAttention) for production.  \n\n* **Direct token‑to‑token communication** – Self‑attention computes a weighted sum of *all* value vectors for each query, giving every token an immediate gradient path to any other token. This eliminates the vanishing‑gradient bottleneck of deep recurrent stacks because the Jacobian contains direct connections across the entire sequence.  \n\n* **Design goals** –  \n  1. **Parallelism**: all queries, keys, and values are produced simultaneously on GPUs/TPUs.  \n  2. **Long‑range dependency capture**: O(1) hops between any two positions.  \n  3. **Flexible context size**: the receptive field equals the full sequence, adjustable at inference time without architectural changes.  \n\nThese properties make self‑attention the backbone of modern NLP and vision transformers.',
#   "## Scaled Dot‑Product Attention: Intuition and Math\n\n**Matrix form**  \nThe core operation is  \n\n\\[\n\\text{Attention}(Q,K,V)=\\operatorname{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right)V\n\\]\n\nwhere *Q*, *K*, *V* ∈ ℝ^{N×d_k} (N = token count).  \n\n*Example (N=2, d_k=4)*  \n\n```python\nimport numpy as np\nQ = np.array([[1,0,2,1],\n              [0,1,1,2]])          # (2,4)\nK = np.array([[1,1,0,2],\n              [2,0,1,1]])          # (2,4)\nV = np.array([[0,1],\n              [1,0]])              # (2,2)\n\nscores = Q @ K.T / np.sqrt(4)      # (2,2)\n# scores ≈ [[(1*1+0*1+2*0+1*2)/2, (1*2+0*0+2*1+1*1)/2],\n#           [(0*1+1*1+1*0+2*2)/2, (0*2+1*0+1*1+2*1)/2]]\n# → [[1.0, 2.5],\n#    [2.5, 1.5]]\n```\n\n**Why √dₖ?**  \nWithout scaling, dot‑products grow with dₖ, pushing softmax into saturated regions (near‑0/1). This yields vanishing gradients. Dividing by √dₖ keeps the variance of the scores ≈1, preserving gradient magnitude.  \n\nA quick sanity check: plot softmax entropy for different dₖ.\n\n```python\nimport matplotlib.pyplot as plt\ndef entropy(x):\n    p = np.exp(x)/np.exp(x).sum()\n    return -np.sum(p*np.log(p+1e-12))\n\nds = [16,256,1024]\nent = [entropy(np.random.randn(1000)*np.sqrt(d)) for d in ds]\nplt.plot(ds, ent, 'o-'); plt.xscale('log'); plt.xlabel('d_k'); plt.ylabel('Entropy')\nplt.show()\n```\n\nHigher dₖ without scaling collapses entropy, confirming instability.\n\n**Masking**  \nCausal or padding masks are added as a large negative bias (e.g., ‑1e9) before softmax:\n\n```python\nmask = np.triu(np.ones((N,N)), k=1)   # causal mask\nbias = mask * -1e9\nattn = softmax((Q @ K.T)/np.sqrt(d_k) + bias)\n```\n\nThe bias forces masked positions to zero probability after softmax.\n\n**Multi‑head extension**  \nFor *h* heads, project the same input *X* → Q,K,V with learned weight matrices W_Q^i ∈ ℝ^{d_model×d_k}, etc., then compute attention per head.\n\nShape flow:  \n\n- X: (N, d_model)  \n- Q_i, K_i, V_i: (N, d_k) after linear projection  \n- head_i output: (N, d_v) after softmax·V_i  \n- Concatenated: (N, h·d_v) → reshape to (N, d_model) via final linear W_O ∈ ℝ^{h·d_v×d_model}.\n\nThis preserves the original dimensionality while allowing each head to attend to different subspaces.",
#   '## Building a Self‑Attention Layer from Scratch (PyTorch MWE)\n\n```python\nimport torch, torch.nn as nn\n\nclass SelfAttention(nn.Module):\n    def __init__(self, dim, heads=4):\n        super().__init__()\n        self.heads, self.scale = heads, (dim // heads) ** -0.5\n        self.qkv = nn.Linear(dim, dim*3, bias=False); self.proj = nn.Linear(dim, dim)\n    def forward(self, x, mask=None):\n        B, N, _ = x.shape\n        q, k, v = self.qkv(x).view(B, N, 3, self.heads, -1).permute(2,0,3,1,4).unbind(0)\n        att = (q @ k.transpose(-2,-1)) * self.scale\n        if mask is not None: att = att.masked_fill(mask==0, float(\'-inf\'))\n        out = (att.softmax(-1) @ v).transpose(1,2).reshape(B, N, -1)\n        return self.proj(out)\n```\n\n### Unit test – sanity‑check output shape\n\n```python\ndef test_self_attention():\n    torch.manual_seed(0)\n    x = torch.randn(2, 8, 32)          # batch=2, seq=8, dim=32\n    sa = SelfAttention(dim=32, heads=4)\n    y = sa(x)                          # forward pass\n    assert y.shape == (2, 8, 32)       # expected shape\ntest_self_attention()\n```\n\n### Profiling per‑head FLOPs & memory\n\n```python\nwith torch.autograd.profiler.profile(use_cuda=False) as prof:\n    y = sa(x)                          # same x as above\n    # The profiler records each matrix multiply (q@k^T) per head.\nprint(prof.key_averages().table(sort_by="self_cpu_memory_usage"))\n# Look for entries like "aten::mm" with count = heads (4) → per‑head FLOPs ≈ 2·N·head_dim²\n```\n\n*Why*: profiling inside the forward pass isolates the expensive attention matmul, helping you spot scaling bottlenecks.\n\n### Swap with `nn.MultiheadAttention` and verify identical output\n\n```python\ntorch.manual_seed(0)                  # same seed guarantees identical weight init\nmh = nn.MultiheadAttention(embed_dim=32, num_heads=4, bias=False)\nmh.in_proj_weight.data = sa.qkv.weight.data.clone()\nmh.out_proj.weight.data = sa.proj.weight.data.clone()\n\n# MultiheadAttention expects (seq, batch, embed_dim)\nx_mh = x.transpose(0, 1)\ny_mh, _ = mh(x_mh, x_mh, x_mh)        # no mask\ny_mh = y_mh.transpose(0, 1)          # back to (batch, seq, dim)\n\nassert torch.allclose(y, y_mh, atol=1e-6)   # identical within floating‑point tolerance\n```\n\n*Trade‑offs*: the handcrafted layer gives full control (e.g., custom masks) at the cost of extra boilerplate; `nn.MultiheadAttention` is battle‑tested, highly optimized, and integrates with PyTorch’s CUDA kernels, reducing maintenance overhead. Edge cases such as mismatched `embed_dim` vs. `heads` raise a clear `AssertionError`; always validate dimensions before instantiation.',
#   '## Performance, Cost, and Edge‑Case Scaling\n\n**Benchmark O(n²) memory growth**  \n```python\nimport torch, time\ndef bench(seq_len):\n    B, D, H = 8, 768, 12\n    x = torch.randn(B, seq_len, D, device=\'cuda\')\n    torch.cuda.reset_peak_memory_stats()\n    start = time.time()\n    q = x @ torch.randn(D, D, device=\'cuda\')\n    k = x @ torch.randn(D, D, device=\'cuda\')\n    v = x @ torch.randn(D, D, device=\'cuda\')\n    attn = torch.softmax(q @ k.transpose(-2, -1) / (D**0.5), dim=-1)\n    out = attn @ v\n    torch.cuda.synchronize()\n    return {\n        "seq_len": seq_len,\n        "peak_MiB": torch.cuda.max_memory_allocated() / 2**20,\n        "runtime_ms": (time.time() - start) * 1e3,\n    }\n\nfor L in (256, 512, 1024):\n    print(bench(L))\n```\nTypical RTX\u202f3090 results:  \n\n| seq_len | peak_MiB | runtime_ms |\n|--------|----------|------------|\n| 256    |  820\u202fMiB |  12\u202fms |\n| 512    | 1\u202f640\u202fMiB|  45\u202fms |\n| 1\u202f024  | 3\u202f280\u202fMiB| 170\u202fms |\n\nMemory scales ≈\u202fO(L²); runtime follows the same quadratic trend.\n\n**Mitigation\u202f(a): Sparse/Local attention**  \n```python\ndef local_attn(x, win=64):\n    B, L, D = x.shape\n    # create a banded mask: 1 inside window, 0 elsewhere\n    mask = torch.ones(L, L, device=x.device).triu(-win).tril(win)\n    q = x @ W_q\n    k = x @ W_k\n    attn = torch.softmax((q @ k.transpose(-2, -1)) * mask, dim=-1)\n    return attn @ (x @ W_v)\n```\n*Why*: reduces quadratic ops to O(L·win), cutting memory and compute for long sequences.\n\n**Mitigation\u202f(b): Reversible/recurrent chunking**  \n```python\ndef chunked_attn(x, chunk=256):\n    outs = []\n    for i in range(0, x.size(1), chunk):\n        chunk_x = x[:, i:i+chunk, :]\n        outs.append(self_attn(chunk_x))          # self_attn uses standard O(n²)\n    return torch.cat(outs, dim=1)\n```\n*Why*: processes manageable slices, keeping peak allocation constant at the cost of extra stitching overhead.\n\n**Failure modes & OOM handling**  \nWhen `seq_len` exceeds GPU capacity the kernel throws `torch.cuda.OutOfMemoryError`. Catch it to fallback to a safe strategy:\n\n```python\ntry:\n    out = self_attn(x)          # may OOM\nexcept torch.cuda.OutOfMemoryError:\n    torch.cuda.empty_cache()\n    out = chunked_attn(x)       # graceful degradation\n```\n\n**Latency impact of more heads**  \nWith `model_dim = 768` and fixed batch size, increasing heads from 4→16 (head_dim drops from 192→48) adds ~2.3× kernel launches:\n\n| heads | runtime_ms (seq_len\u202f=\u202f512) |\n|------|----------------------------|\n| 4    | 38\u202fms |\n| 16   | 88\u202fms |\n\nMore heads improve expressivity but linearly increase kernel overhead and memory traffic. Choose the smallest head count that meets accuracy requirements.',
#   '## Common Mistakes When Using Self‑Attention  \n\n- **Forgetting the √dₖ scaling** – The attention logits are computed as `Q·Kᵀ`. Without dividing by `sqrt(d_k)` the softmax saturates, gradients explode and the loss curve diverges (often “nan” after a few steps).  \n  ```python\n  # buggy\n  scores = torch.matmul(Q, K.transpose(-2, -1))          # no scaling\n  # correct\n  scale = math.sqrt(Q.size(-1))\n  scores = torch.matmul(Q, K.transpose(-2, -1)) / scale\n  ```  \n  *Trade‑off*: scaling adds a negligible compute cost but stabilises training.  \n\n- **Applying padding mask after softmax** – Masking the output probabilities leaves the masked positions with non‑zero attention weight, corrupting the context vector.  \n  ```python\n  # wrong\n  attn = torch.softmax(scores, dim=-1)\n  attn = attn.masked_fill(pad_mask, 0.0)   # post‑softmax\n  # right\n  scores = scores.masked_fill(pad_mask, -1e9)  # pre‑softmax\n  attn = torch.softmax(scores, dim=-1)\n  ```  \n  The pre‑softmax mask forces the softmax to assign ~0 probability to padded tokens.  \n\n- **Re‑using the same linear layer for Q, K, V** – Sharing one weight matrix reduces the rank of the joint projection, limiting the model’s ability to learn distinct query, key, and value subspaces.  \n  ```diff\n  - self.qkv = nn.Linear(dim, dim * 3, bias=False)\n  + self.q_proj = nn.Linear(dim, dim, bias=False)\n  + self.k_proj = nn.Linear(dim, dim, bias=False)\n  + self.v_proj = nn.Linear(dim, dim, bias=False)\n  ```  \n  *Why*: separate matrices increase expressive power with only a linear increase in parameters.  \n\n- **Neglecting dtype consistency** – Mixing `fp16` queries with `fp32` keys (or values) causes implicit casts, hidden precision loss, and occasional `RuntimeError: matmul not supported for these dtypes`.  \n  ```python\n  print(Q.dtype, K.dtype)          # debug tip\n  K = K.to(Q.dtype)                # fix\n  ```  \n  Ensure all three tensors share the same `dtype` before the matmul; otherwise cast them explicitly.  \n\n*Edge case*: when using mixed‑precision training, wrap the projection block with `torch.autocast` to keep dtype uniform automatically.',
#   '## Production Checklist & Next Steps\n\n- **Validate numerical stability**  \n  - Run a gradient‑norm sanity check on a few batches:  \n\n    ```python\n    grads = torch.autograd.grad(loss, model.parameters(), create_graph=False)\n    gn = torch.norm(torch.stack([g.norm() for g in grads]))\n    assert not torch.isnan(gn), "NaN detected in attention gradients"\n    ```  \n\n  - Log the norm; abort training if it spikes >\u202f2× the running median.  \n  - *Why*: early detection prevents silent divergence that corrupts downstream services.\n\n- **Enable observability**  \n  - Emit per‑step attention entropy `H = -∑a·log(a)` and head‑wise latency to Prometheus/TensorBoard:  \n\n    ```python\n    entropy = -(attn * attn.log()).sum(dim=-1).mean()\n    logger.metric("attention.entropy", entropy.item())\n    logger.metric("attention.latency_ms", latency_ms)\n    ```  \n\n  - Tag metrics with `model_version` and `head_id` for drill‑down.  \n\n- **Security/privacy**  \n  - Ensure raw input tokens never reach logs. Add a scrubbing hook before any logging middleware:  \n\n    ```python\n    def scrub(tokens):\n        return ["<redacted>" if t.is_sensitive else t for t in tokens]\n    logger.add_hook(lambda rec: rec.update(tokens=scrub(rec["tokens"])))\n    ```  \n\n  - *Why*: compliance with GDPR/CCPA and prevents token leakage.\n\n- **Performance gating**  \n  - CI benchmark example (pytest + `timeit`):  \n\n    ```yaml\n    - name: Attention runtime test\n      run: |\n        runtime=$(python bench_attention.py)\n        baseline=0.120  # seconds\n        [[ $(python -c "print(runtime/baseline)") < 1.10 ]]\n    ```  \n\n  - Fails the pipeline if runtime exceeds 10\u202f% over the baseline MWE.  \n\n- **Roadmap ideas**  \n  - Try FlashAttention for O(1) memory overhead.  \n  - Evaluate ALiBi positional bias to remove absolute position embeddings.  \n  - Prototype dynamic‑length chunking to reduce padding waste.  \n\nFollow this list to ship a robust self‑attention module and iterate safely toward higher throughput and richer modeling features.'],
#  'final': '# Demystifying Self‑Attention: From Theory to Production‑Ready Code\n\n## Why Self‑Attention? The problem it solves  \n\n* **RNN/CNN receptive field vs. sequence length** – In a 512‑token sentiment classifier, a vanilla LSTM processes tokens one‑by‑one, so the hidden state at position\u202f512 has only seen 511 previous steps through a single recurrent path. A 1‑D CNN with kernel\u202f3 and 4 layers reaches a receptive field of\u202f3\u202f+\u202f2·(4‑1)\u202f=\u202f9 tokens, leaving 503 tokens outside the context. Neither architecture can natively attend to the whole 512‑token span without stacking many layers, which inflates latency and memory.  \n\n* **Timing chart (theoretical ops)**  \n\n| Sequence length *n* | Recurrence (O(n)) | Self‑attention (O(n²)) |\n|---------------------|-------------------|------------------------|\n| 128                 | 128\u202f×\u202fC           | 16\u202f384\u202f×\u202fC             |\n| 512                 | 512\u202f×\u202fC           | 262\u202f144\u202f×\u202fC            |\n| 2048                | 2\u202f048\u202f×\u202fC         | 4\u202f194\u202f304\u202f×\u202fC          |\n\n*C = constant per‑element work.* The table shows that for short sequences recurrence is cheaper, but the quadratic term dominates as *n* grows, motivating optimized attention kernels (e.g., FlashAttention) for production.  \n\n* **Direct token‑to‑token communication** – Self‑attention computes a weighted sum of *all* value vectors for each query, giving every token an immediate gradient path to any other token. This eliminates the vanishing‑gradient bottleneck of deep recurrent stacks because the Jacobian contains direct connections across the entire sequence.  \n\n* **Design goals** –  \n  1. **Parallelism**: all queries, keys, and values are produced simultaneously on GPUs/TPUs.  \n  2. **Long‑range dependency capture**: O(1) hops between any two positions.  \n  3. **Flexible context size**: the receptive field equals the full sequence, adjustable at inference time without architectural changes.  \n\nThese properties make self‑attention the backbone of modern NLP and vision transformers.\n\n## Scaled Dot‑Product Attention: Intuition and Math\n\n**Matrix form**  \nThe core operation is  \n\n\\[\n\\text{Attention}(Q,K,V)=\\operatorname{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right)V\n\\]\n\nwhere *Q*, *K*, *V* ∈ ℝ^{N×d_k} (N = token count).  \n\n*Example (N=2, d_k=4)*  \n\n```python\nimport numpy as np\nQ = np.array([[1,0,2,1],\n              [0,1,1,2]])          # (2,4)\nK = np.array([[1,1,0,2],\n              [2,0,1,1]])          # (2,4)\nV = np.array([[0,1],\n              [1,0]])              # (2,2)\n\nscores = Q @ K.T / np.sqrt(4)      # (2,2)\n# scores ≈ [[(1*1+0*1+2*0+1*2)/2, (1*2+0*0+2*1+1*1)/2],\n#           [(0*1+1*1+1*0+2*2)/2, (0*2+1*0+1*1+2*1)/2]]\n# → [[1.0, 2.5],\n#    [2.5, 1.5]]\n```\n\n**Why √dₖ?**  \nWithout scaling, dot‑products grow with dₖ, pushing softmax into saturated regions (near‑0/1). This yields vanishing gradients. Dividing by √dₖ keeps the variance of the scores ≈1, preserving gradient magnitude.  \n\nA quick sanity check: plot softmax entropy for different dₖ.\n\n```python\nimport matplotlib.pyplot as plt\ndef entropy(x):\n    p = np.exp(x)/np.exp(x).sum()\n    return -np.sum(p*np.log(p+1e-12))\n\nds = [16,256,1024]\nent = [entropy(np.random.randn(1000)*np.sqrt(d)) for d in ds]\nplt.plot(ds, ent, \'o-\'); plt.xscale(\'log\'); plt.xlabel(\'d_k\'); plt.ylabel(\'Entropy\')\nplt.show()\n```\n\nHigher dₖ without scaling collapses entropy, confirming instability.\n\n**Masking**  \nCausal or padding masks are added as a large negative bias (e.g., ‑1e9) before softmax:\n\n```python\nmask = np.triu(np.ones((N,N)), k=1)   # causal mask\nbias = mask * -1e9\nattn = softmax((Q @ K.T)/np.sqrt(d_k) + bias)\n```\n\nThe bias forces masked positions to zero probability after softmax.\n\n**Multi‑head extension**  \nFor *h* heads, project the same input *X* → Q,K,V with learn ...
